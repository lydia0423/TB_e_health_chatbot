# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset/hospital_selangor.csv")
df.head(n=5)
# Out:
#    _id  TAHUN    NEGERI  KOD_GT                     NAMA_KEM_KESIHATAN  \
# 0    1   2017  Selangor  TIS204  Hospital Tengku Ampuan Rahimah (HTAR)
# 1    2   2017  Selangor  TIS204                      Hospital Selayang
# 2    3   2017  Selangor  TIS204                       Hospital Serdang
# 3    4   2017  Selangor  TIS204                  Hospital Sungai Buloh
# 4    5   2017  Selangor  TIS204                        Hospital Ampang
#
#                                            ALAMAT       DAERAH  \
# 0                        Jalan Langat,41200 Klang        Klang
# 1      Lebuhraya Selayang-Kepong,68100 Batu Caves       Gombak
# 2                      Jalan Puchong,43000 Kajang  Hulu Langat
# 3               Jalan Hospital,47000 Sungai Buloh     Petaling
# 4  Jalan Mewah UtaraÂ ,Pandan Mewah, 68000 Ampang  Hulu Langat
#
#                                SEMASA AKTIVITI_1 AKTIVITI_2  ...  BIL_DOKTOR  \
# 0  Institusi Dan Kemudahan Masyarakat  Kesihatan   Hospital  ...         676
# ...

# %%
hospital_area = df.DAERAH
print(hospital_area)
# Out:
# 0              Klang
# 1             Gombak
# 2        Hulu Langat
# 3           Petaling
# 4        Hulu Langat
# 5        Hulu Langat
# 6           Petaling
# 7       Kuala Langat
# 8      Hulu Selangor
# 9     Kuala Selangor
# 10      Sabak Bernam
# 11            Gombak
# 12       Hulu Langat
# 13       Hulu Langat
# 14       Hulu Langat
# 15       Hulu Langat
# 16       Hulu Langat
# 17       Hulu Langat
# 18       Hulu Langat
# 19     Hulu Selangor
# 20          Petaling
# 21          Petaling
# 22          Petaling
# 23          Petaling
# 24          Petaling
# 25          Petaling
# 26          Petaling
# 27          Petaling
# 28          Petaling
# 29          Petaling
# 30          Petaling
# 31          Petaling
# 32          Petaling
# 33          Petaling
# 34          Petaling
# 35          Petaling
# 36          Petaling
# 37          Petaling
# 38          Petaling
# 39          Petaling
# 40          Petaling
# 41     Hulu Selangor
# Name: DAERAH, dtype: object

# %%
df['COUNT'] = 1 
df.groupby(['DAERAH', 'NAMA_KEM_KESIHATAN']).count()["COUNT"]
# Out:
# DAERAH          NAMA_KEM_KESIHATAN
# Gombak          Hospital Orang Asli Gombak                            1
#                 Hospital Selayang                                     1
# Hulu Langat     Hospital Ampang                                       1
#                 Hospital Kajang                                       1
#                 Hospital PUSRAWARI SMC                                1
#                 Hospital Pakar Ampang Puteri                          1
#                 Hospital Pakar An-Nur Hasanah                         1
#                 Hospital Pantai Ampang                                1
#                 Hospital Serdang                                      1
#                 KPJ Kajang Specelish Hospital                         1
#                 Kajang Medical Centre                                 1
#                 Kajang Plaza Medical Centre                           1
# Hulu Selangor   Hospital Kuala Kubu Bharu                             2
# ...
